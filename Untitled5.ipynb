# %% [markdown]
# Python Assignment

# %%
'''1.Explain the key features of Python that make it a popular choice for programming.'''
features = [
     "Easy to use and learn",
 "python is an integrated language",
 "large communite",
 "Object criented programming language",
 "Python is a dynamically typed language",
 "GUI programming support"
 ]

# %%
'''2.Describe the role of predefined keywords in Python and provide examples of how they are used in a program.'''
predefined_keywords = ['print', 'int', 'float'] # Corrected syntax for list definition

# %%
'''3.Compare and contrast mutable and immutable objects in Python with examples'''
list = [10,15,30]
tuple =(100,150,300)
print(list)
print(tuple)
# Out:
# [10, 15, 30]
# (100, 150, 300)

# %%
list[0]=20
print(list)
# Out:
# [20, 15, 30]

# %%
#because the error tuple can be mutable
tuple[0]=200
print(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-35a68fd5cafc> in <cell line: 1>()
# ----> 1 tuple[0]=200
#       2 print(tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
'''4.Discuss the different types of operators in Python and provide examples of how they are used'''
operator = ["Arithmetic operator","Assignment operator","Comparison operator","Logical operator","Bitwise operator","Identity operator","Membership operator"]

# %%
 '''5Explain the concept of type casting in Python with examples'''
 a = 2
 b= "3"

# %%
a +b
tybe(a)
tybe(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-5df9ca2a327e> in <cell line: 1>()
# ----> 1 a +b
#       2 tybe(a)
#       3 tybe(b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'''5.How do conditional statements work in Python? Illustrate with examples'''
age = 20
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are eligible to vote.

# %%
age = 17
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are not eligible to vote.

# %%
'''6. Describe the different types of loops in Python and their use cases with examples.'''
count = 5
while count > 0:
    print(count)
    count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
files.download('python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d49d425720a7> in <cell line: 1>()
# ----> 1 files.download('python')
#
# NameError: name 'files' is not defined
